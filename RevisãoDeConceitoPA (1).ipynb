# %% [markdown]
# # REVISÃO DE CONCEITOS DE **PA**

# %% [markdown]
# Operadores:
#
# AND,OR,XOR,NOT

# %%
#Operador Lógicao OU
True and False

# %%
#Operador Lógicao E
False and False

# %%
True or False and False

# %% [markdown]
# # Estruturas de Decisão

# %% [markdown]
# if (Condição):
#
# código se condição VERDADEIRA
#
# else:
#
# codigo Se condução FALSA

# %%
vai_chover = True

if (vai_chover == False):
 print("Não Precisa Levar Guarda-Chuva")
else:
 print("Precisa Levar Guarda-Chuva")

# %% [markdown]
# Faça um programa que receba um idade do usuário e informe se ele é ou não maior de idade

# %%
idade = int(input("Digite sua idade: "))
print("A variavel idade é do tipo:]", type(idade))
soma = idade + 20
soma
idade
# Out:
# Digite sua idade: 16
# A variavel idade é do tipo:] <class 'int'>
# 16

# %%
if idade >= 18:
  print("Você é maior de idade")
else:
  print("Você é menor de idade")
# Out:
# Você é maior de idade

# %% [markdown]
# **Faça um programa que informe se o usuário pode ou não dirigir um veículo. Para isso peça a idade do usuário e também se ele tem habiloitação ou não.Para habilitação receba como resposta : SIM ou NÃO**

# %%
idade = int(input("Digite sua idade: "))
# Out:
# Digite sua idade: 19

# %%
if idade >= 18:
 habilitacao = input("Você possui habilitação? Digite SIM ou NÃO: ")
 if habilitacao == "SIM" or habilitacao == "Sim" or  habilitacao == "sim":
  print("Você pode dirigir")
 else:
   print("Você não pode dirigir")
else:
   print("Você não pode dirigir porque é menor de idade")
# Out:
# Você possui habilitação? Digite SIM ou NÃO: sim
# Você pode dirigir
