# %% [markdown]
# # **Exemplo**

# %%
nome = "Brayan"
idade = 14
year = 2024

# %%
print(year)
# Out:
# 2024

# %%
print(nome)
# Out:
# Brayan

# %%
idade
# Out:
# 14

# %%
print("seu nome é", nome )
# Out:
# seu nome é Brayan

# %%
print("sua idade é", idade)
# Out:
# sua idade é 14

# %%
print("Sua idade é",idade,"anos de idade")
# Out:
# Sua idade é 14 anos de idade

# %%
print("Seu nome é",nome,"\n\nSua idade é",idade,"anos de idade")
# Out:
# Seu nome é Brayan
#
# Sua idade é 14 anos de idade

# %% [markdown]
# ## **Operadores Aritméticos**

# %%
n1 = 7
n2 = 8
n3 = 10

# %%
media = (n1+n2+n3)/3
media
# Out:
# 8.333333333333334

# %%
print("Sua média é", media)
# Out:
# Sua média é 8.333333333333334

# %%
round(media,1)
# Out:
# 8.3

# %%
print("Sua média é", round(media,1))
# Out:
# Sua média é 8.3

# %%
nome = input("Digite seu nome:")
nome
# Out:
# Digite seu nome:brayan
# 'brayan'

# %%
ano_nasc = input("Digete seu ano de nascimento:")
ano_nasc
# Out:
# Digete seu ano de nascimento:2009
# '2009'

# %%
idade = 2024 - ano_nasc
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-e9b1fb0d3b69> in <cell line: 1>()
# ----> 1 idade = 2024 - ano_nasc
#
# TypeError: unsupported operand type(s) for -: 'int' and 'str'

# %%
type(ano_nasc)

str
# Out:
# str

# %%
ano_nasc = int(ano_nasc)

# %%
type(ano_nasc)
# Out:
# int

# %%
idade = 2024 - ano_nasc
idade
# Out:
# 15

# %%
x = 7
# obtendo o resto da divisão x por 2
divisao_normal = x / 2
resto = x % 2
quociente = x // 2

print("Divisão Normal",divisao_normal)
print("Resto - mod %",resto)
print("Quociente - div //",quociente)
# Out:
# Divisão Normal 3.5
# Resto - mod % 1
# Quociente - div // 3
